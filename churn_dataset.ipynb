# %%
import pandas as pd
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df.Churn = encoder.fit_transform(df['Churn'])

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
c_mat = df.corr()

fig = plt.figure(figsize=(15, 15))
sns.heatmap(c_mat, vmax=0.8, square=True)
plt.show()
# Out:
# C:\Users\Vignesh\AppData\Local\Temp\ipykernel_3060\368682571.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c_mat = df.corr()

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
ax=sns.countplot(x="gender",data=df)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' containing the data

# Pie chart for 'PaymentMethod'
payment_method_counts = df['PaymentMethod'].value_counts()
labels = payment_method_counts.index
sizes = payment_method_counts.values

plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Pie Chart: PaymentMethod')
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is circular.
plt.show()

# %%
ax=sns.countplot(x="SeniorCitizen",data=df)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' containing the data

columns = [ 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
           'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
           'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
           'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
           'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']

# Iterate over the columns
for column in columns:
    plt.figure(figsize=(8, 6))  # Set the size of the plot
    sns.countplot(data=df, x=column)  # Create the countplot
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
    plt.title(f"Countplot of {column}")  # Set the title of the plot
    plt.show()  # Display the plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' containing the data

columns = [ 'PhoneService', 'MultipleLines', 'InternetService',
           'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
           'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
            'Churn']

# Calculate the number of rows and columns for subplots
num_rows = 7  # Change this value to adjust the number of rows
num_cols = 3  # Change this value to adjust the number of columns

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 25))
fig.subplots_adjust(hspace=0.5)  # Adjust the vertical spacing between subplots

# Iterate over the columns
for i, column in enumerate(columns):
    row = i // num_cols  # Calculate the row index
    col = i % num_cols  # Calculate the column index

    sns.countplot(data=df, x=column, ax=axes[row, col])  # Create the countplot
    axes[row, col].set_xticklabels(axes[row, col].get_xticklabels(), rotation=45)  # Rotate x-axis labels for better readability
    axes[row, col].set_title(f"Countplot of {column}")  # Set the title of the plot

# Remove empty subplots if the number of columns is not a multiple of num_cols
if i < (num_rows * num_cols) - 1:
    for j in range(i + 1, num_rows * num_cols):
        fig.delaxes(axes[j // num_cols, j % num_cols])

plt.tight_layout()  # Adjust the layout of subplots to prevent overlapping
plt.show()  # Display the plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' containing the data

# Line plot for 'gender' against 'Churn'
sns.relplot(data=df, x="gender", y="Churn", kind="line")
plt.title('Line Plot: Churn vs Gender')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' containing the data

# Line plot for 'Partner' against 'Churn'
sns.relplot(data=df, x="Partner", y="Churn", kind="line")
plt.title('Line Plot: Churn vs Partner')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' containing the data

# Line plot for 'Dependents' against 'Churn'
sns.relplot(data=df, x="Dependents", y="Churn", kind="line")
plt.title('Line Plot: Churn vs Dependents')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' containing the data

# Bar chart for 'Dependents' against 'Churn'
sns.barplot(data=df, x="Dependents", y="Churn")
plt.title('Bar Chart: Churn vs Dependents')
plt.show()
